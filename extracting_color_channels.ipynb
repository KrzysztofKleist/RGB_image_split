# %%
from extract_colors_and_plot import extract_color_channels, plot_all_images

# %%
plot_all_images(*extract_color_channels('sample_image.jpg'))

# %%
plot_all_images(*extract_color_channels('sample_image_1.jpg'))
